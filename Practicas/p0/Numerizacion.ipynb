# %%
ColabNotebook = 'google.colab' in str(get_ipython())

if ColabNotebook:
    # monta G-drive en entorno COLAB
    from google.colab import drive
    drive.mount('/content/drive/')

    DATOS_DIR = '/content/drive/MyDrive/Colab Notebooks/DATOS/'  # carpeta donde se encuentran los datasets
else:
    DATOS_DIR   = '../../Datos/' # carpeta LOCAL donde se encuentran los datasets

# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import chardet

# Set the option to opt-in to the future behavior
pd.set_option('future.no_silent_downcasting', True)

# %%
nomArch = DATOS_DIR + 'Premios2020.csv'
#-- detectando la codificación de caracteres usada ----
with open(nomArch, 'rb') as f:
    result = chardet.detect(f.read())  # or readline if the file is large

df= pd.read_csv(nomArch, encoding=result['encoding'])

# %% [markdown]
# # Datos faltantes

# %% [markdown]
# **Completando los datos faltantes del atributo release**

# %%
moda = df['release'].mode()
df['release'] = df['release'].replace([np.nan], moda)

df['release'].value_counts()
# Out:
# release
# December     32
# January      25
# November     22
# February     22
# October      20
# June         12
# September    11
# April         9
# July          9
# August        8
# March         8
# May           8
# Name: count, dtype: int64

# %%
df
# Out:
#      Year  Age                            Actor Sex              Film  \
# 0    1928   44                    Emil Jannings   M  The Last Command
# 1    1928   22  Laura Gainor (aka Janet Gaynor)   F           Sunrise
# 2    1929   37                    Mary Pickford   F          Coquette
# 3    1929   38                    Warner Baxter   M    In Old Arizona
# 4    1930   62                    George Arliss   M          Disraeli
# ..    ...  ...                              ...  ..               ...
# 181  2018   44                    Olivia Colman   F     The Favourite
# 182  2019   50                  Renée Zellweger   F              Judy
# 183  2019   45                  Joaquin Phoenix   M             Joker
# 184  2020   63                Frances McDormand   F         Nomadland
# 185  2020   83                  Anthony Hopkins   M        The father
#
#      nominations  rating  duration     genre1    genre2    release  \
# 0            2.0     8.0        88      Drama   History      April
# 1            5.0     7.8       110      Drama   Romance   December
# 2            1.0     7.3        76      Drama   Romance      April
# 3            5.0     5.8        95    Romance   Western    January
# 4            3.0     6.5        90  Biography     Drama   November
# ..           ...     ...       ...        ...       ...        ...
# 181         10.0     7.5       119     Comedy     Drama   December
# 182          2.0     6.8       118  Biography     Drama   February
# 183         11.0     8.5       122      Drama  Thriller    October
# 184          6.0     7.4       108      Drama       NaN  September
# 185          6.0     8.3        97      Drama       NaN    January
#
#                                               synopsis
# 0    A former Imperial Russian general and cousin o...
# 1    A street cleaner saves a young womans life and...
# 2    A flirtatious southern belle is compromised wi...
# 3    A charming happy-go-lucky bandit in old Arizon...
# 4    Prime Minister of Great Britain Benjamin Disra...
# ..                                                 ...
# 181  In the early 18th century England is at war wi...
# 182  Thirty years after starring in "The Wizard of ...
# 183  Arthur Fleck loves to make people laugh but hi...
# 184  Nomadland es una película estadounidense de dr...
# 185  Anthony tiene casi 83 años. Vive solo en su ap...
#
# [186 rows x 12 columns]

# %% [markdown]
# # Numerización

# %% [markdown]
# ## Numerización como entero único

# %%
mapeo = {"release": {"January":1, "February":2, "March":3,"April":4,
                "May":5, "June":6,"July":7, "August":8, "September":9,
                     "October":10, "November":11, "December":12}}

df.replace(mapeo, inplace=True)
print(df['release'].describe())
# Out:
# count     186
# unique     12
# top        12
# freq       32
# Name: release, dtype: int64

# %%
df
# Out:
#      Year  Age                            Actor Sex              Film  \
# 0    1928   44                    Emil Jannings   M  The Last Command
# 1    1928   22  Laura Gainor (aka Janet Gaynor)   F           Sunrise
# 2    1929   37                    Mary Pickford   F          Coquette
# 3    1929   38                    Warner Baxter   M    In Old Arizona
# 4    1930   62                    George Arliss   M          Disraeli
# ..    ...  ...                              ...  ..               ...
# 181  2018   44                    Olivia Colman   F     The Favourite
# 182  2019   50                  Renée Zellweger   F              Judy
# 183  2019   45                  Joaquin Phoenix   M             Joker
# 184  2020   63                Frances McDormand   F         Nomadland
# 185  2020   83                  Anthony Hopkins   M        The father
#
#      nominations  rating  duration     genre1    genre2 release  \
# 0            2.0     8.0        88      Drama   History       4
# 1            5.0     7.8       110      Drama   Romance      12
# 2            1.0     7.3        76      Drama   Romance       4
# 3            5.0     5.8        95    Romance   Western       1
# 4            3.0     6.5        90  Biography     Drama      11
# ..           ...     ...       ...        ...       ...     ...
# 181         10.0     7.5       119     Comedy     Drama      12
# 182          2.0     6.8       118  Biography     Drama       2
# 183         11.0     8.5       122      Drama  Thriller      10
# 184          6.0     7.4       108      Drama       NaN       9
# 185          6.0     8.3        97      Drama       NaN       1
#
#                                               synopsis
# 0    A former Imperial Russian general and cousin o...
# 1    A street cleaner saves a young womans life and...
# 2    A flirtatious southern belle is compromised wi...
# 3    A charming happy-go-lucky bandit in old Arizon...
# 4    Prime Minister of Great Britain Benjamin Disra...
# ..                                                 ...
# 181  In the early 18th century England is at war wi...
# 182  Thirty years after starring in "The Wizard of ...
# 183  Arthur Fleck loves to make people laugh but hi...
# 184  Nomadland es una película estadounidense de dr...
# 185  Anthony tiene casi 83 años. Vive solo en su ap...
#
# [186 rows x 12 columns]

# %% [markdown]
# ## Numerización binaria

# %%
# atributo sexo con codificación binaria
NuevasColumnas = pd.get_dummies(df['Sex'], prefix= 'Sex', drop_first=True).astype(int)

# Agregamos las nuevas columnas al DataFrame
df = pd.concat([NuevasColumnas, df], axis=1)

# Borramos la columna anterior
df.drop(['Sex'],axis=1, inplace=True)

df
# Out:
#      Sex_M  Year  Age                            Actor              Film  \
# 0        1  1928   44                    Emil Jannings  The Last Command
# 1        0  1928   22  Laura Gainor (aka Janet Gaynor)           Sunrise
# 2        0  1929   37                    Mary Pickford          Coquette
# 3        1  1929   38                    Warner Baxter    In Old Arizona
# 4        1  1930   62                    George Arliss          Disraeli
# ..     ...   ...  ...                              ...               ...
# 181      0  2018   44                    Olivia Colman     The Favourite
# 182      0  2019   50                  Renée Zellweger              Judy
# 183      1  2019   45                  Joaquin Phoenix             Joker
# 184      0  2020   63                Frances McDormand         Nomadland
# 185      1  2020   83                  Anthony Hopkins        The father
#
#      nominations  rating  duration     genre1    genre2 release  \
# 0            2.0     8.0        88      Drama   History       4
# 1            5.0     7.8       110      Drama   Romance      12
# 2            1.0     7.3        76      Drama   Romance       4
# 3            5.0     5.8        95    Romance   Western       1
# 4            3.0     6.5        90  Biography     Drama      11
# ..           ...     ...       ...        ...       ...     ...
# 181         10.0     7.5       119     Comedy     Drama      12
# 182          2.0     6.8       118  Biography     Drama       2
# 183         11.0     8.5       122      Drama  Thriller      10
# 184          6.0     7.4       108      Drama       NaN       9
# 185          6.0     8.3        97      Drama       NaN       1
#
#                                               synopsis
# 0    A former Imperial Russian general and cousin o...
# 1    A street cleaner saves a young womans life and...
# 2    A flirtatious southern belle is compromised wi...
# 3    A charming happy-go-lucky bandit in old Arizon...
# 4    Prime Minister of Great Britain Benjamin Disra...
# ..                                                 ...
# 181  In the early 18th century England is at war wi...
# 182  Thirty years after starring in "The Wizard of ...
# 183  Arthur Fleck loves to make people laugh but hi...
# 184  Nomadland es una película estadounidense de dr...
# 185  Anthony tiene casi 83 años. Vive solo en su ap...
#
# [186 rows x 12 columns]
